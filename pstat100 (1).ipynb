# %%
import pandas as pd
import numpy as np
import altair as alt

# %% [markdown]
# ## Green House Gases Emission

# %% [markdown]
# This project will cover annual greenhouse gases(GHG) emissions given the activities and countries that produced the GH in the past five years from 2017 to 2021. GHG emission was and has been one of the most controversial topics worldwide. Some says that it is inevitable because of the industrial revolution happening around the world. Some says that human civilization could control the emission to its lowest as economic activities continued to thrive. In this project, we will utilize and explore the dataset provided by IMF data library which is free for users to access.

# %% [markdown]
# ### Data Description

# %% [markdown]
# The orginal website leads us to the GHG data set is [World Bank Open Data](https://datacatalog.worldbank.org/home). Then we navigate to data catalog and find library network where we further to access [IMF data library](https://climatedata.imf.org/). It is convienent for us to access the GHG data because it is on the dashboard.

# %% [markdown]
# There are a lot of variables in the data set. After looking through the table provided by the IMF website, we decided to narrow down our interested variables to the following:
#
# `Country`: The country name
# `Indicator`: General description of GHG
# `Industry`: The activities causing the GHG emission
# `Gas_Type`: Types of GHG gases

# %%
ghg = pd.read_csv('data/Annual_GHG.csv', encoding = 'latin-1')

# %%
ghg = ghg.loc[:,['Country', 'ISO3', 'Indicator','Industry','Gas_Type','Unit'\
                 ,'F2017','F2018','F2019','F2020','F2021']]
ghg.head(10)
# Out:
#               Country   ISO3  \
# 0  Advanced Economies  AETMP
# 1  Advanced Economies  AETMP
# 2  Advanced Economies  AETMP
# 3  Advanced Economies  AETMP
# 4  Advanced Economies  AETMP
# 5  Advanced Economies  AETMP
# 6  Advanced Economies  AETMP
# 7  Advanced Economies  AETMP
# 8  Advanced Economies  AETMP
# 9  Advanced Economies  AETMP
#
#                                            Indicator  \
# 0  Annual greenhouse gas (GHG) air emissions acco...
# 1  Annual greenhouse gas (GHG) air emissions acco...
# 2  Annual greenhouse gas (GHG) air emissions acco...
# 3  Annual greenhouse gas (GHG) air emissions acco...
# 4  Annual greenhouse gas (GHG) air emissions acco...
# 5  Annual greenhouse gas (GHG) air emissions acco...
# 6  Annual greenhouse gas (GHG) air emissions acco...
# 7  Annual greenhouse gas (GHG) air emissions acco...
# 8  Annual greenhouse gas (GHG) air emissions acco...
# 9  Annual greenhouse gas (GHG) air emissions acco...
#
# ...
